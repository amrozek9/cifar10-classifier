# %%
import torchvision
import matplotlib.pyplot as plt

train_set = torchvision.datasets.CIFAR10("../data", train=True, download=True)
classes = train_set.classes
print(len(train_set), "training images")
print(classes)

fig, axes = plt.subplots(2, 5, figsize=(10, 4))
for i, ax in enumerate(axes.flat):
    img, label = train_set[i]
    ax.imshow(img)
    ax.set_title(classes[label])
    ax.axis("off")
plt.show()
# Out:
# Running cells with '.venv (3.14.7.final.0) (Python 3.14.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/mroze/Documents/cifar10-classifier/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
